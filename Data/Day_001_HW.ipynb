# %% [markdown]
# '''
# 一,
# 選擇資料：https://www.kaggle.com/lava18/google-play-store-apps#googleplaystore-user_reviews.csv
# 1.完成Apps 後改善的方向可以建立在大多數使用者使用過後的心得及建議
# 2.Google Store Apps 評分
# 3.結構化資料
# 4.改善方向:正確率
#
# 二,
# 1.在相同的工作時間及人力下,提升載客量
# 2.主要載客區人群在不同時間流量,從附近上班族群及前往地區探討
# 3.結構化資料
# 4.在同一個地區值得投入人力的時間,根據分析後結果實驗是否載客量提升
#
# '''

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(T, E):
    """
    T: 估計函數
    E: 無法觀察參數
    """
    mae = sum(abs(T-E)) / len(E)
    return mae

# %%
def mean_squared_error(T, E):
    """
    T: 估計函數
    E: 無法觀察參數
    """
    mse = sum(np.square(T-E)) / len(E)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 10.761
# The Mean absolute error is 10.761
